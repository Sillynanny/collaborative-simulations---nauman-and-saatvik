# %%
#this will be a collaborative simulation of a harmonic oscillator, that includes friction, dampening, and a driving force, with Saatvik K

#goal: investigate how coulomb (dry) friction affects energy transfer, resonance, and the motion of an oscilltor system.

#how: we'll simulate the position, velocity, and energies of a mass-spring system without viscous dampening and dry friction, then with viscous dampening, and then with viscous dampening and dry friction. all will consider a driving force (F_0*cos(omega*t)). the first two rounds (the ones without dry friction) will set a baseline of how no dampening and viscous dampening only affect resonance, energy transfer, and motion of the oscillator to compare against the dry friction round. furthermore, we will plot resonance curves that compare resonance frequencies omega vs. amplitudes of the curve for each round

#expected results: we expect to see resonance occur at the natural frequency of the mass-spring system, and we also expect the usual loss of mechanical energy due to dampening and friction. additionally, we expect to notice very little error in any rk4 approximations against analytical solutions due to the accuracy of rk4.

#extra: for all equations without dry friction, we'll compare rk4 approximations with the analytical solution, as excluding dry friction allows us to easily derive analytical solutions from the differential equations using laplace transforms

#note for us: use matplotlib for the graphs and manim to actually animate the oscillator. this cell will include any information needed for the project. each round of the simulation (no viscous dampening and dry friction, viscous dampening, viscous dampening and dry friction) will have their own cell, and there will be a cell at the end for observations, comparisons, and analysis of results. add manim after everything listed previously is done.
#note #2: we are gonna move the goal, "how", expected results, and extra to a google slideshow, where they will be rewritten and properly punctuated. additionally, we'll input images of the graphs into the slideshow, as well as analyses. all of this information will be kept here as well and there will still be multiple cells to eliminate the redundancy of using a notebook instead of a .py file.

# %%
# %%matplotlib inline
# %%matplotlib notebook
#
# import numpy as np
# import matplotlib.pyplot as plt
